# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>
# Your task is to design new DNNs for ECG signal classification <br>
# You can use this file as a template

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: CNN

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv1d(1, 64, kernel_size=3, padding=1),
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.norm3 = nn.BatchNorm1d(64)
        self.conv3 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.norm4 = nn.BatchNorm1d(64)
        self.conv4 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.norm5 = nn.BatchNorm1d(64)
        self.conv5 = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        feature_size = (187 // 8) * 64

        self.fc1 = nn.Sequential(
            nn.Linear(feature_size, 1024),
            nn.ReLU(),
        )
        self.fc2 = nn.Linear(1024, 5)

    def forward(self, x):
        x1 = self.conv1(x)
        x1a = self.pool1(x1)

        x2c = self.conv2(x1a)
        x2 = x2c + x1a
        x2a = self.pool2(x2)

        x3c = self.conv3(self.norm3(x2a))
        x3 = x3c + x2a
        x3a = self.pool3(x3)

        x4c = self.conv4(self.norm4(x3a))
        x4 = x4c + x3a

        x5 = self.conv5(self.norm5(x4))

        x5r = x5.view(x5.size(0), -1)

        x6 = self.fc1(x5r)
        z = self.fc2(x6)
        #y=nnF.softmax(z, dim=1)
        return z

# %%
#debug your network here
#make sure it works 
model=CNN()
x=torch.rand(10,1,187) # since network is CNN
z=model(x)
# Out:
# [W NNPACK.cpp:61] Could not initialize NNPACK! Reason: Unsupported hardware.

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders
# ### You may need to edit MyDataset

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        x=x.reshape(1,-1) # if network is CNN
        return x, y

# %% [markdown]
# Attention: this dataset does not have class-imbalance issue.

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=CNN()
model.to(device)
x=dataset_train[0][0]
x=x.view(1, 1, 187).to(device) #change it to x=x.view(1,1,187).to(device) for CNN
z=model(x)

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.2234, 0.1862, 0.2065, 0.1861, 0.1978]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    #change the name of the file if necessary
    save_checkpoint('ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.610683
# epoch 0 training loss: 0.799447010863911 acc: 0.7051374819102749
# /var/folders/xs/czdjg8q54cz21bqm4kfr5zz80000gn/T/ipykernel_2181/3076453557.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   prec[n]=TP/(TP+FP)
# epoch 0 validation acc: 0.19155844
# saved: ECG_MLP_Pytorch_epoch0.pt
# Train Epoch: 1 [0%]	Loss: 0.467122
# epoch 1 training loss: 0.4449270963668823 acc: 0.8382778581765558
# epoch 1 validation acc: 0.5064935
# saved: ECG_MLP_Pytorch_epoch1.pt
# Train Epoch: 2 [0%]	Loss: 0.347181
# epoch 2 training loss: 0.34770258787003433 acc: 0.8726483357452967
# epoch 2 validation acc: 0.7987013
# saved: ECG_MLP_Pytorch_epoch2.pt
# Train Epoch: 3 [0%]	Loss: 0.365459
# epoch 3 training loss: 0.2941947430372238 acc: 0.8932706222865412
# epoch 3 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch3.pt
# Train Epoch: 4 [0%]	Loss: 0.181635
# epoch 4 training loss: 0.24824860285628925 acc: 0.9106367583212736
# epoch 4 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch4.pt
# Train Epoch: 5 [0%]	Loss: 0.257212
# epoch 5 training loss: 0.20610239627686414 acc: 0.9254703328509407
# epoch 5 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch5.pt
# Train Epoch: 6 [0%]	Loss: 0.171226
# epoch 6 training loss: 0.17604400725527244 acc: 0.9413892908827786
# epoch 6 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch6.pt
# Train Epoch: 7 [0%]	Loss: 0.176600
# epoch 7 training loss: 0.1453516994687644 acc: 0.9522431259044862
# epoch 7 validation acc: 0.8084416
# saved: ECG_MLP_Pytorch_epoch7.pt
# Train Epoch: 8 [0%]	Loss: 0.090257
# epoch 8 training loss: 0.12954753095453436 acc: 0.9587554269175108
# epoch 8 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch8.pt
# Train Epoch: 9 [0%]	Loss: 0.164172
# epoch 9 training loss: 0.10589142922650684 acc: 0.967438494934877
# epoch 9 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch9.pt
# Train Epoch: 10 [0%]	Loss: 0.103189
# epoch 10 training loss: 0.09958100132644176 acc: 0.9685238784370478
# epoch 10 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch10.pt
# Train Epoch: 11 [0%]	Loss: 0.052127
# epoch 11 training loss: 0.08113905872133645 acc: 0.9768451519536903
# epoch 11 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch11.pt
# Train Epoch: 12 [0%]	Loss: 0.103162
# epoch 12 training loss: 0.07707613198594614 acc: 0.9775687409551375
# epoch 12 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch12.pt
# Train Epoch: 13 [0%]	Loss: 0.090000
# epoch 13 training loss: 0.06596378643404353 acc: 0.9819102749638206
# epoch 13 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch13.pt
# Train Epoch: 14 [0%]	Loss: 0.088052
# epoch 14 training loss: 0.06206105107610876 acc: 0.9829956584659914
# epoch 14 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch14.pt
# Train Epoch: 15 [0%]	Loss: 0.018883
# epoch 15 training loss: 0.05244269636882977 acc: 0.9884225759768451
# epoch 15 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch15.pt
# Train Epoch: 16 [0%]	Loss: 0.081586
# epoch 16 training loss: 0.04924793050370433 acc: 0.9866136034732272
# epoch 16 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch16.pt
# Train Epoch: 17 [0%]	Loss: 0.026916
# epoch 17 training loss: 0.04087883115492084 acc: 0.9902315484804631
# epoch 17 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch17.pt
# Train Epoch: 18 [0%]	Loss: 0.042860
# epoch 18 training loss: 0.03417209760201248 acc: 0.993849493487699
# epoch 18 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch18.pt
# Train Epoch: 19 [0%]	Loss: 0.015403
# epoch 19 training loss: 0.03913264835930683 acc: 0.9891461649782923
# epoch 19 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch19.pt
# Train Epoch: 20 [0%]	Loss: 0.035105
# epoch 20 training loss: 0.03734612816267393 acc: 0.9887843704775687
# epoch 20 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch20.pt
# Train Epoch: 21 [0%]	Loss: 0.047078
# epoch 21 training loss: 0.031102611471644857 acc: 0.992040520984081
# epoch 21 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch21.pt
# Train Epoch: 22 [0%]	Loss: 0.007509
# epoch 22 training loss: 0.021073719634759156 acc: 0.9963820549927641
# epoch 22 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch22.pt
# Train Epoch: 23 [0%]	Loss: 0.015343
# epoch 23 training loss: 0.01955226935784925 acc: 0.9952966714905933
# epoch 23 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch23.pt
# Train Epoch: 24 [0%]	Loss: 0.006577
# epoch 24 training loss: 0.01818334704942324 acc: 0.9960202604920405
# epoch 24 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch24.pt
# Train Epoch: 25 [0%]	Loss: 0.013218
# epoch 25 training loss: 0.01743292563002218 acc: 0.9956584659913169
# epoch 25 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch25.pt
# Train Epoch: 26 [0%]	Loss: 0.008807
# epoch 26 training loss: 0.01603961663997986 acc: 0.9963820549927641
# epoch 26 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch26.pt
# Train Epoch: 27 [0%]	Loss: 0.007335
# epoch 27 training loss: 0.015641661106862804 acc: 0.9963820549927641
# epoch 27 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch27.pt
# Train Epoch: 28 [0%]	Loss: 0.015744
# epoch 28 training loss: 0.015404135920107365 acc: 0.9967438494934877
# epoch 28 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch28.pt
# Train Epoch: 29 [0%]	Loss: 0.025233
# epoch 29 training loss: 0.014771026474508371 acc: 0.9952966714905933
# epoch 29 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch29.pt
# Train Epoch: 30 [0%]	Loss: 0.006892
# epoch 30 training loss: 0.013414294353093614 acc: 0.9971056439942113
# epoch 30 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch30.pt
# Train Epoch: 31 [0%]	Loss: 0.016283
# epoch 31 training loss: 0.017063058732839472 acc: 0.9956584659913169
# epoch 31 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch31.pt
# Train Epoch: 32 [0%]	Loss: 0.006555
# epoch 32 training loss: 0.016686590134420178 acc: 0.9949348769898697
# epoch 32 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch32.pt
# Train Epoch: 33 [0%]	Loss: 0.009818
# epoch 33 training loss: 0.014339509716426784 acc: 0.9960202604920405
# epoch 33 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch33.pt
# Train Epoch: 34 [0%]	Loss: 0.004134
# epoch 34 training loss: 0.014129704859277064 acc: 0.9960202604920405
# epoch 34 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch34.pt
# Train Epoch: 35 [0%]	Loss: 0.004362
# epoch 35 training loss: 0.014498016363094475 acc: 0.9960202604920405
# epoch 35 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch35.pt
# Train Epoch: 36 [0%]	Loss: 0.007553
# epoch 36 training loss: 0.011304552582177248 acc: 0.9971056439942113
# epoch 36 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch36.pt
# Train Epoch: 37 [0%]	Loss: 0.003338
# epoch 37 training loss: 0.008646726872856643 acc: 0.9974674384949349
# epoch 37 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch37.pt
# Train Epoch: 38 [0%]	Loss: 0.008158
# epoch 38 training loss: 0.01736657841088758 acc: 0.9949348769898697
# epoch 38 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch38.pt
# Train Epoch: 39 [0%]	Loss: 0.009642
# epoch 39 training loss: 0.01862962406382642 acc: 0.9949348769898697
# epoch 39 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch39.pt
# Train Epoch: 40 [0%]	Loss: 0.007138
# epoch 40 training loss: 0.007950966182926839 acc: 0.9989146164978292
# epoch 40 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch40.pt
# Train Epoch: 41 [0%]	Loss: 0.012806
# epoch 41 training loss: 0.00680153238565915 acc: 0.9985528219971056
# epoch 41 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch41.pt
# Train Epoch: 42 [0%]	Loss: 0.021165
# epoch 42 training loss: 0.006786829522091218 acc: 0.9974674384949349
# epoch 42 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch42.pt
# Train Epoch: 43 [0%]	Loss: 0.002665
# epoch 43 training loss: 0.004325663115278902 acc: 0.9992764109985528
# epoch 43 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch43.pt
# Train Epoch: 44 [0%]	Loss: 0.003110
# epoch 44 training loss: 0.005920983263587748 acc: 0.9985528219971056
# epoch 44 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch44.pt
# Train Epoch: 45 [0%]	Loss: 0.009506
# epoch 45 training loss: 0.005980487717103891 acc: 0.9985528219971056
# epoch 45 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch45.pt
# Train Epoch: 46 [0%]	Loss: 0.005046
# epoch 46 training loss: 0.005305259514981034 acc: 0.9996382054992764
# epoch 46 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch46.pt
# Train Epoch: 47 [0%]	Loss: 0.004141
# epoch 47 training loss: 0.0033936030707660725 acc: 0.9996382054992764
# epoch 47 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch47.pt
# Train Epoch: 48 [0%]	Loss: 0.003538
# epoch 48 training loss: 0.003058962185274471 acc: 1.0
# epoch 48 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch48.pt
# Train Epoch: 49 [0%]	Loss: 0.003550
# epoch 49 training loss: 0.002371821952031248 acc: 0.9996382054992764
# epoch 49 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch49.pt
# Train Epoch: 50 [0%]	Loss: 0.001123
# epoch 50 training loss: 0.0023818307619711213 acc: 0.9996382054992764
# epoch 50 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch50.pt
# Train Epoch: 51 [0%]	Loss: 0.005194
# epoch 51 training loss: 0.0026670217656911436 acc: 0.9996382054992764
# epoch 51 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch51.pt
# Train Epoch: 52 [0%]	Loss: 0.001918
# epoch 52 training loss: 0.0026006273269145327 acc: 0.9992764109985528
# epoch 52 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch52.pt
# Train Epoch: 53 [0%]	Loss: 0.016032
# epoch 53 training loss: 0.0036694079224782235 acc: 0.9992764109985528
# epoch 53 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch53.pt
# Train Epoch: 54 [0%]	Loss: 0.003866
# epoch 54 training loss: 0.003747279713438316 acc: 0.9989146164978292
# epoch 54 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch54.pt
# Train Epoch: 55 [0%]	Loss: 0.001541
# epoch 55 training loss: 0.002801300201099366 acc: 0.9996382054992764
# epoch 55 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch55.pt
# Train Epoch: 56 [0%]	Loss: 0.010300
# epoch 56 training loss: 0.003706770152679052 acc: 0.9992764109985528
# epoch 56 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch56.pt
# Train Epoch: 57 [0%]	Loss: 0.003597
# epoch 57 training loss: 0.0036193512443622403 acc: 1.0
# epoch 57 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch57.pt
# Train Epoch: 58 [0%]	Loss: 0.002907
# epoch 58 training loss: 0.008805854404768483 acc: 0.9974674384949349
# epoch 58 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch58.pt
# Train Epoch: 59 [0%]	Loss: 0.004057
# epoch 59 training loss: 0.0042124385045926 acc: 0.9996382054992764
# epoch 59 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch59.pt
# Train Epoch: 60 [0%]	Loss: 0.001798
# epoch 60 training loss: 0.002948860193348744 acc: 1.0
# epoch 60 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch60.pt
# Train Epoch: 61 [0%]	Loss: 0.002207
# epoch 61 training loss: 0.0049178112478164785 acc: 0.998191027496382
# epoch 61 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch61.pt
# Train Epoch: 62 [0%]	Loss: 0.001163
# epoch 62 training loss: 0.003452349877492948 acc: 1.0
# epoch 62 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch62.pt
# Train Epoch: 63 [0%]	Loss: 0.002760
# epoch 63 training loss: 0.002142608631402254 acc: 1.0
# epoch 63 validation acc: 0.8733766
# saved: ECG_MLP_Pytorch_epoch63.pt
# Train Epoch: 64 [0%]	Loss: 0.001304
# epoch 64 training loss: 0.0030913746661760592 acc: 0.9996382054992764
# epoch 64 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch64.pt
# Train Epoch: 65 [0%]	Loss: 0.027675
# epoch 65 training loss: 0.006173124722078104 acc: 0.9985528219971056
# epoch 65 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch65.pt
# Train Epoch: 66 [0%]	Loss: 0.001408
# epoch 66 training loss: 0.008452822274359112 acc: 0.9974674384949349
# epoch 66 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch66.pt
# Train Epoch: 67 [0%]	Loss: 0.003218
# epoch 67 training loss: 0.00612730303758078 acc: 0.9989146164978292
# epoch 67 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch67.pt
# Train Epoch: 68 [0%]	Loss: 0.004074
# epoch 68 training loss: 0.007605246617458761 acc: 0.9978292329956585
# epoch 68 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch68.pt
# Train Epoch: 69 [0%]	Loss: 0.028922
# epoch 69 training loss: 0.009969139185903425 acc: 0.9971056439942113
# epoch 69 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch69.pt
# Train Epoch: 70 [0%]	Loss: 0.029484
# epoch 70 training loss: 0.011638250413604757 acc: 0.9960202604920405
# epoch 70 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch70.pt
# Train Epoch: 71 [0%]	Loss: 0.003182
# epoch 71 training loss: 0.005492680097549138 acc: 0.998191027496382
# epoch 71 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch71.pt
# Train Epoch: 72 [0%]	Loss: 0.002372
# epoch 72 training loss: 0.0039703982289541855 acc: 0.9989146164978292
# epoch 72 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch72.pt
# Train Epoch: 73 [0%]	Loss: 0.001053
# epoch 73 training loss: 0.0021643394522305407 acc: 0.9996382054992764
# epoch 73 validation acc: 0.89285713
# saved: ECG_MLP_Pytorch_epoch73.pt
# Train Epoch: 74 [0%]	Loss: 0.000748
# epoch 74 training loss: 0.0016412125868638132 acc: 1.0
# epoch 74 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch74.pt
# Train Epoch: 75 [0%]	Loss: 0.000989
# epoch 75 training loss: 0.0011286659864708781 acc: 1.0
# epoch 75 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch75.pt
# Train Epoch: 76 [0%]	Loss: 0.000344
# epoch 76 training loss: 0.0007318221892505376 acc: 1.0
# epoch 76 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch76.pt
# Train Epoch: 77 [0%]	Loss: 0.000428
# epoch 77 training loss: 0.0007039274761072276 acc: 1.0
# epoch 77 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch77.pt
# Train Epoch: 78 [0%]	Loss: 0.000567
# epoch 78 training loss: 0.0006762996001105586 acc: 1.0
# epoch 78 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch78.pt
# Train Epoch: 79 [0%]	Loss: 0.000429
# epoch 79 training loss: 0.0005917683540081435 acc: 1.0
# epoch 79 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch79.pt
# Train Epoch: 80 [0%]	Loss: 0.000380
# epoch 80 training loss: 0.0006131791623457419 acc: 1.0
# epoch 80 validation acc: 0.8766234
# saved: ECG_MLP_Pytorch_epoch80.pt
# Train Epoch: 81 [0%]	Loss: 0.000570
# epoch 81 training loss: 0.0005828410503454506 acc: 1.0
# epoch 81 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch81.pt
# Train Epoch: 82 [0%]	Loss: 0.001052
# epoch 82 training loss: 0.0006682250479405576 acc: 1.0
# epoch 82 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch82.pt
# Train Epoch: 83 [0%]	Loss: 0.000359
# epoch 83 training loss: 0.0005659322017560374 acc: 1.0
# epoch 83 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch83.pt
# Train Epoch: 84 [0%]	Loss: 0.000458
# epoch 84 training loss: 0.0005271404105852442 acc: 1.0
# epoch 84 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch84.pt
# Train Epoch: 85 [0%]	Loss: 0.000613
# epoch 85 training loss: 0.0005665188522967087 acc: 1.0
# epoch 85 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch85.pt
# Train Epoch: 86 [0%]	Loss: 0.000367
# epoch 86 training loss: 0.0005512469559272921 acc: 1.0
# epoch 86 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch86.pt
# Train Epoch: 87 [0%]	Loss: 0.000331
# epoch 87 training loss: 0.0005895517943744463 acc: 1.0
# epoch 87 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch87.pt
# Train Epoch: 88 [0%]	Loss: 0.000430
# epoch 88 training loss: 0.0005179216472738931 acc: 1.0
# epoch 88 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch88.pt
# Train Epoch: 89 [0%]	Loss: 0.000400
# epoch 89 training loss: 0.0004847277186027813 acc: 1.0
# epoch 89 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch89.pt
# Train Epoch: 90 [0%]	Loss: 0.000328
# epoch 90 training loss: 0.0005008431881750849 acc: 1.0
# epoch 90 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch90.pt
# Train Epoch: 91 [0%]	Loss: 0.000507
# epoch 91 training loss: 0.0005591597450389104 acc: 1.0
# epoch 91 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch91.pt
# Train Epoch: 92 [0%]	Loss: 0.000372
# epoch 92 training loss: 0.0007440914381401275 acc: 1.0
# epoch 92 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch92.pt
# Train Epoch: 93 [0%]	Loss: 0.000691
# epoch 93 training loss: 0.0017995388585735452 acc: 0.9992764109985528
# epoch 93 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch93.pt
# Train Epoch: 94 [0%]	Loss: 0.015070
# epoch 94 training loss: 0.0022043107336768035 acc: 0.9992764109985528
# epoch 94 validation acc: 0.8896104
# saved: ECG_MLP_Pytorch_epoch94.pt
# Train Epoch: 95 [0%]	Loss: 0.001614
# epoch 95 training loss: 0.0010898141838631338 acc: 1.0
# epoch 95 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch95.pt
# Train Epoch: 96 [0%]	Loss: 0.000976
# epoch 96 training loss: 0.0006952550915726038 acc: 1.0
# epoch 96 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch96.pt
# Train Epoch: 97 [0%]	Loss: 0.000426
# epoch 97 training loss: 0.0005639444623904473 acc: 1.0
# epoch 97 validation acc: 0.8863636
# saved: ECG_MLP_Pytorch_epoch97.pt
# Train Epoch: 98 [0%]	Loss: 0.001524
# epoch 98 training loss: 0.0005638795740775425 acc: 1.0
# epoch 98 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch98.pt
# Train Epoch: 99 [0%]	Loss: 0.000634
# epoch 99 training loss: 0.0004905288859101182 acc: 1.0
# epoch 99 validation acc: 0.8831169
# saved: ECG_MLP_Pytorch_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 73

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=CNN()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.91937584
# Sensitivity [0.85795456 0.91558444 0.92465752 0.95901638 0.95321637]
# Precision [0.86285716 0.86503065 0.95744681 0.93599999 0.9878788 ]
# Confusion
#  [[151.  19.   2.   3.   1.]
#  [ 12. 141.   1.   0.   0.]
#  [  4.   1. 135.   5.   1.]
#  [  4.   0.   1. 117.   0.]
#  [  4.   2.   2.   0. 163.]]
