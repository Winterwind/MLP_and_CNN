# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>
# Your task is to design new DNNs for ECG signal classification <br>
# You can use this file as a template

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(in_features=187, out_features=256)
        self.linear2 = nn.Linear(256, 256)
        self.norm3 = nn.BatchNorm1d(256)
        self.linear3 = nn.Linear(256, 256, self.norm3)
        self.norm4 = nn.BatchNorm1d(256)
        self.linear4 = nn.Linear(256, 256, self.norm4)
        self.norm5 = nn.BatchNorm1d(256)
        self.linear5 = nn.Linear(256, 256, self.norm5)
        self.linear6 = nn.Linear(256, 5)
    def forward(self, x):
        x1=nnF.relu(self.linear1(x))
        x2=nnF.relu(self.linear2(x1))
        x3=nnF.relu(self.linear3(x2))
        x4=nnF.relu(self.linear4(x3))
        x5=nnF.relu(self.linear5(x4))
        z=self.linear6(x5)
        #y=nnF.softmax(z, dim=1)
        return z

# %%
#debug your network here
#make sure it works 
model=Net()
x=torch.rand(10,187)
#x=torch.rand(10,1,187) if network is CNN
z=model(x)

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders
# ### You may need to edit MyDataset

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        #x=x.reshape(1,-1) if network is CNN
        return x, y

# %% [markdown]
# Attention: this dataset does not have class-imbalance issue.

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
x=dataset_train[0][0]
x=x.view(1,187).to(device) #change it to x=x.view(1,1,187).to(device) for CNN
z=model(x)

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.1929, 0.1859, 0.2080, 0.2102, 0.2030]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    #change the name of the file if necessary
    save_checkpoint('H4P2T1_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.610989
# epoch 0 training loss: 1.5487291379408403 acc: 0.3194645441389291
# epoch 0 validation acc: 0.36688313
# saved: H4P2T1_epoch0.pt
# Train Epoch: 1 [0%]	Loss: 1.380822
# /var/folders/xs/czdjg8q54cz21bqm4kfr5zz80000gn/T/ipykernel_2878/3076453557.py:13: RuntimeWarning: invalid value encountered in scalar divide
#   prec[n]=TP/(TP+FP)
# epoch 1 training loss: 1.2434270490299573 acc: 0.5289435600578871
# epoch 1 validation acc: 0.512987
# saved: H4P2T1_epoch1.pt
# Train Epoch: 2 [0%]	Loss: 1.013151
# epoch 2 training loss: 1.0298009975390001 acc: 0.6005788712011577
# epoch 2 validation acc: 0.59090906
# saved: H4P2T1_epoch2.pt
# Train Epoch: 3 [0%]	Loss: 0.963923
# epoch 3 training loss: 0.9397735406051982 acc: 0.625904486251809
# epoch 3 validation acc: 0.6266234
# saved: H4P2T1_epoch3.pt
# Train Epoch: 4 [0%]	Loss: 0.994119
# epoch 4 training loss: 0.8677623895081606 acc: 0.6743849493487699
# epoch 4 validation acc: 0.66883117
# saved: H4P2T1_epoch4.pt
# Train Epoch: 5 [0%]	Loss: 0.863226
# epoch 5 training loss: 0.8075132451274178 acc: 0.7007959479015919
# epoch 5 validation acc: 0.6883117
# saved: H4P2T1_epoch5.pt
# Train Epoch: 6 [0%]	Loss: 0.818428
# epoch 6 training loss: 0.7664796357805078 acc: 0.7196092619392185
# epoch 6 validation acc: 0.6980519
# saved: H4P2T1_epoch6.pt
# Train Epoch: 7 [0%]	Loss: 0.669886
# epoch 7 training loss: 0.7137589793313633 acc: 0.7431259044862518
# epoch 7 validation acc: 0.71753246
# saved: H4P2T1_epoch7.pt
# Train Epoch: 8 [0%]	Loss: 0.681876
# epoch 8 training loss: 0.6864776150746779 acc: 0.7492764109985528
# epoch 8 validation acc: 0.73376626
# saved: H4P2T1_epoch8.pt
# Train Epoch: 9 [0%]	Loss: 0.598361
# epoch 9 training loss: 0.6547808105295355 acc: 0.7633863965267728
# epoch 9 validation acc: 0.72727275
# saved: H4P2T1_epoch9.pt
# Train Epoch: 10 [0%]	Loss: 0.736642
# epoch 10 training loss: 0.6198219331828031 acc: 0.776410998552822
# epoch 10 validation acc: 0.72402596
# saved: H4P2T1_epoch10.pt
# Train Epoch: 11 [0%]	Loss:
epoch56.pt
# Train Epoch: 57 [0%]	Loss: 0.180403
# epoch 57 training loss: 0.16309002211148088 acc: 0.9424746743849494
# epoch 57 validation acc: 0.8214286
# saved: H4P2T1_epoch57.pt
# Train Epoch: 58 [0%]	Loss: 0.229097
# epoch 58 training loss: 0.1727867123078216 acc: 0.9392185238784371
# epoch 58 validation acc: 0.8279221
# saved: H4P2T1_epoch58.pt
# Train Epoch: 59 [0%]	Loss: 0.192859
# epoch 59 training loss: 0.1633954139595682 acc: 0.9439218523878437
# epoch 59 validation acc: 0.8246753
# saved: H4P2T1_epoch59.pt
# Train Epoch: 60 [0%]	Loss: 0.092691
# epoch 60 training loss: 0.14863823794505812 acc: 0.9511577424023154
# epoch 60 validation acc: 0.84415585
# saved: H4P2T1_epoch60.pt
# Train Epoch: 61 [0%]	Loss: 0.088962
# epoch 61 training loss: 0.15838273005052048 acc: 0.9421128798842258
# epoch 61 validation acc: 0.8246753
# saved: H4P2T1_epoch61.pt
# Train Epoch: 62 [0%]	Loss: 0.240995
# epoch 62 training loss: 0.16205036944963716 acc: 0.9457308248914617
# epoch 62 validation acc: 0.85714287
# saved: H4P2T1_epoch62.pt
# Train Epoch: 63 [0%]	Loss: 0.099889
# epoch 63 training loss: 0.1378165947442705 acc: 0.9551374819102749
# epoch 63 validation acc: 0.8279221
# saved: H4P2T1_epoch63.pt
# Train Epoch: 64 [0%]	Loss: 0.136950
# epoch 64 training loss: 0.1336268037557602 acc: 0.9587554269175108
# epoch 64 validation acc: 0.84415585
# saved: H4P2T1_epoch64.pt
# Train Epoch: 65 [0%]	Loss: 0.112303
# epoch 65 training loss: 0.14103929122740572 acc: 0.9500723589001447
# epoch 65 validation acc: 0.8603896
# saved: H4P2T1_epoch65.pt
# Train Epoch: 66 [0%]	Loss: 0.081917
# epoch 66 training loss: 0.1264843652871522 acc: 0.959479015918958
# epoch 66 validation acc: 0.8474026
# saved: H4P2T1_epoch66.pt
# Train Epoch: 67 [0%]	Loss: 0.141217
# epoch 67 training loss: 0.11525080623951825 acc: 0.9645441389290883
# epoch 67 validation acc: 0.84415585
# saved: H4P2T1_epoch67.pt
# Train Epoch: 68 [0%]	Loss: 0.105501
# epoch 68 training loss: 0.12085442448204214 acc: 0.9598408104196816
# epoch 68 validation acc: 0.8149351
# saved: H4P2T1_epoch68.pt
# Train Epoch: 69 [0%]	Loss: 0.079172
# epoch 69 training loss: 0.12073510682040994 acc: 0.961287988422576
# epoch 69 validation acc: 0.84090906
# saved: H4P2T1_epoch69.pt
# Train Epoch: 70 [0%]	Loss: 0.114174
# epoch 70 training loss: 0.11660572954199531 acc: 0.9598408104196816
# epoch 70 validation acc: 0.85714287
# saved: H4P2T1_epoch70.pt
# Train Epoch: 71 [0%]	Loss: 0.141330
# epoch 71 training loss: 0.15814673172479327 acc: 0.9377713458755427
# epoch 71 validation acc: 0.8538961
# saved: H4P2T1_epoch71.pt
# Train Epoch: 72 [0%]	Loss: 0.145910
# epoch 72 training loss: 0.12738606638529085 acc: 0.9573082489146165
# epoch 72 validation acc: 0.84415585
# saved: H4P2T1_epoch72.pt
# Train Epoch: 73 [0%]	Loss: 0.093468
# epoch 73 training loss: 0.10644887590950186 acc: 0.9670767004341534
# epoch 73 validation acc: 0.83766234
# saved: H4P2T1_epoch73.pt
# Train Epoch: 74 [0%]	Loss: 0.083326
# epoch 74 training loss: 0.10375864820724184 acc: 0.9652677279305355
# epoch 74 validation acc: 0.84090906
# saved: H4P2T1_epoch74.pt
# Train Epoch: 75 [0%]	Loss: 0.055963
# epoch 75 training loss: 0.09727976538918236 acc: 0.9681620839363242
# epoch 75 validation acc: 0.8538961
# saved: H4P2T1_epoch75.pt
# Train Epoch: 76 [0%]	Loss: 0.066866
# epoch 76 training loss: 0.09140720099888065 acc: 0.9725036179450073
# epoch 76 validation acc: 0.84090906
# saved: H4P2T1_epoch76.pt
# Train Epoch: 77 [0%]	Loss: 0.059666
# epoch 77 training loss: 0.08918527970937165 acc: 0.9725036179450073
# epoch 77 validation acc: 0.8474026
# saved: H4P2T1_epoch77.pt
# Train Epoch: 78 [0%]	Loss: 0.140137
# epoch 78 training loss: 0.08722438874908468 acc: 0.973589001447178
# epoch 78 validation acc: 0.83116883
# saved: H4P2T1_epoch78.pt
# Train Epoch: 79 [0%]	Loss: 0.039032
# epoch 79 training loss: 0.08721756274727258 acc: 0.975397973950796
# epoch 79 validation acc: 0.84415585
# saved: H4P2T1_epoch79.pt
# Train Epoch: 80 [0%]	Loss: 0.040876
# epoch 80 training loss: 0.07915172200988639 acc: 0.9757597684515196
# epoch 80 validation acc: 0.85714287
# saved: H4P2T1_epoch80.pt
# Train Epoch: 81 [0%]	Loss: 0.074215
# epoch 81 training loss: 0.10469611768018115 acc: 0.9659913169319826
# epoch 81 validation acc: 0.84090906
# saved: H4P2T1_epoch81.pt
# Train Epoch: 82 [0%]	Loss: 0.134524
# epoch 82 training loss: 0.08309938809411092 acc: 0.9725036179450073
# epoch 82 validation acc: 0.83441556
# saved: H4P2T1_epoch82.pt
# Train Epoch: 83 [0%]	Loss: 0.089331
# epoch 83 training loss: 0.08313944427804514 acc: 0.9743125904486252
# epoch 83 validation acc: 0.85064936
# saved: H4P2T1_epoch83.pt
# Train Epoch: 84 [0%]	Loss: 0.069498
# epoch 84 training loss: 0.07962375049563972 acc: 0.9728654124457308
# epoch 84 validation acc: 0.83441556
# saved: H4P2T1_epoch84.pt
# Train Epoch: 85 [0%]	Loss: 0.058862
# epoch 85 training loss: 0.08060415512458845 acc: 0.973589001447178
# epoch 85 validation acc: 0.84415585
# saved: H4P2T1_epoch85.pt
# Train Epoch: 86 [0%]	Loss: 0.070308
# epoch 86 training loss: 0.08237653818320144 acc: 0.9750361794500724
# epoch 86 validation acc: 0.83766234
# saved: H4P2T1_epoch86.pt
# Train Epoch: 87 [0%]	Loss: 0.097435
# epoch 87 training loss: 0.07700277492403984 acc: 0.9761215629522432
# epoch 87 validation acc: 0.8474026
# saved: H4P2T1_epoch87.pt
# Train Epoch: 88 [0%]	Loss: 0.096190
# epoch 88 training loss: 0.07456644675271078 acc: 0.9772069464544139
# epoch 88 validation acc: 0.85064936
# saved: H4P2T1_epoch88.pt
# Train Epoch: 89 [0%]	Loss: 0.067633
# epoch 89 training loss: 0.06842734850943089 acc: 0.9772069464544139
# epoch 89 validation acc: 0.84090906
# saved: H4P2T1_epoch89.pt
# Train Epoch: 90 [0%]	Loss: 0.058027
# epoch 90 training loss: 0.059284908612343395 acc: 0.9848046309696092
# epoch 90 validation acc: 0.84415585
# saved: H4P2T1_epoch90.pt
# Train Epoch: 91 [0%]	Loss: 0.037363
# epoch 91 training loss: 0.0688567663627592 acc: 0.9761215629522432
# epoch 91 validation acc: 0.8279221
# saved: H4P2T1_epoch91.pt
# Train Epoch: 92 [0%]	Loss: 0.063714
# epoch 92 training loss: 0.06770972179418261 acc: 0.9786541244573083
# epoch 92 validation acc: 0.84090906
# saved: H4P2T1_epoch92.pt
# Train Epoch: 93 [0%]	Loss: 0.081533
# epoch 93 training loss: 0.07448791560124267 acc: 0.9761215629522432
# epoch 93 validation acc: 0.84415585
# saved: H4P2T1_epoch93.pt
# Train Epoch: 94 [0%]	Loss: 0.037537
# epoch 94 training loss: 0.06326164643872868 acc: 0.9797395079594791
# epoch 94 validation acc: 0.84415585
# saved: H4P2T1_epoch94.pt
# Train Epoch: 95 [0%]	Loss: 0.017173
# epoch 95 training loss: 0.059655901129272854 acc: 0.9844428364688856
# epoch 95 validation acc: 0.84415585
# saved: H4P2T1_epoch95.pt
# Train Epoch: 96 [0%]	Loss: 0.053635
# epoch 96 training loss: 0.056813198226419365 acc: 0.981548480463097
# epoch 96 validation acc: 0.85064936
# saved: H4P2T1_epoch96.pt
# Train Epoch: 97 [0%]	Loss: 0.036961
# epoch 97 training loss: 0.057788225737485016 acc: 0.9811866859623734
# epoch 97 validation acc: 0.83766234
# saved: H4P2T1_epoch97.pt
# Train Epoch: 98 [0%]	Loss: 0.083606
# epoch 98 training loss: 0.055187745866450394 acc: 0.9851664254703328
# epoch 98 validation acc: 0.85064936
# saved: H4P2T1_epoch98.pt
# Train Epoch: 99 [0%]	Loss: 0.025857
# epoch 99 training loss: 0.06421897653490305 acc: 0.9786541244573083
# epoch 99 validation acc: 0.8474026
# saved: H4P2T1_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 65

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.8530559
# Sensitivity [0.67613637 0.87012988 0.94520545 0.86885244 0.92982459]
# Precision [0.8321678  0.80239522 0.80701756 0.89830506 0.93529409]
# Confusion
#  [[119.  29.  15.   6.   7.]
#  [ 14. 134.   4.   1.   1.]
#  [  1.   0. 138.   5.   2.]
#  [  7.   0.   8. 106.   1.]
#  [  2.   4.   6.   0. 159.]]
